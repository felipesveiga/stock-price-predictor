# %%
# Converter os índices para trimestre.

# %% [markdown]
# <h1 style='font-size:40px'> Stock Price Predictor</h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             The present project aims to create a stock price predictor using the corporations' fundamentals.
#         </li>
#         <li>
#             The model must estimate the given quarter's 80th percentile using the financial statements from the previous quarter.
#         </li>
#     </ul>
# </div>

# %%
from yfinance import Ticker
petr3 = Ticker('PETR3.SA')

# %%
from yfinance import Ticker
petr3_quarterly_balance_sheet = petr3.quarterly_balance_sheet.T
petr3_quarterly_financials = petr3.quarterly_financials.T
petr3_quarterly_cashflow = petr3.quarterly_cashflow.T
petr3_quarterly_earnings = petr3.quarterly_earnings

# %%
pd.PeriodIndex(petr3_quarterly_balance_sheet.columns, freq='Q')
# Out:
# PeriodIndex(['2022Q1', '2021Q4', '2021Q3', '2021Q2'], dtype='period[Q-DEC]', name='')

# %%
petr3_quarterly_cashflow
# Out:
#              Investments  Change To Liabilities  \
#
# 2022-03-31 -2.494000e+09          -1.267000e+09
# 2021-12-31 -7.590000e+08           1.208000e+09
# 2021-09-30  1.370000e+08           2.621000e+09
# 2021-06-30  3.540000e+08          -1.537000e+09
#
#             Total Cashflows From Investing Activities  Net Borrowings  \
#
# 2022-03-31                              -4.983000e+09   -1.381700e+10
# 2021-12-31                               3.108000e+09   -1.250100e+10
# 2021-09-30                               2.057900e+10   -4.379900e+10
# 2021-06-30                              -5.187000e+09   -5.418100e+10
#
#             Total Cash From Financing Activities  \
#
# 2022-03-31                         -1.645500e+10
# 2021-12-31                         -5.573200e+10
# 2021-09-30                         -6.821600e+10
# 2021-06-30                         -6.552700e+10
#
#             Change To Operating Activities    Net Income  Change In Cash  \
#
# ...
